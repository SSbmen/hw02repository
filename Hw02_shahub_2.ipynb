# %% [markdown]
# <a href="https://colab.research.google.com/github/SSbmen/hw02repository/blob/main/Hw02_shahub_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from re import A
# # connect google drive to colab notebook
# from google.colab import drive
# drive.mount('/content/drive')
# # Mounted at /content/drive

# # initialize repository in Github
# !git init hw02repository-2
# # Initialized empty Git repository in /content/hw02repository-2/.git/

# # read and display image stored in drive
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# img=mpimg.imread('sandwich.jpg')
# imgplot = plt.imshow(img)

# Apply laplace filter to image
from scipy import ndimage, misc
result = ndimage.laplace(img)
# Display filtered image
imgplot_filtered = plt.imshow(result)
